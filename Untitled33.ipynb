# %% [markdown]
# <a href="https://colab.research.google.com/github/christy5165/NLP-Practicals/blob/main/Untitled33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.util import trigrams

# Download required NLTK datasets
nltk.download('punkt')
nltk.download('punkt_tab')

# Input sentence
text = "Deep learning is a subset of machine learning."

# Step 1: Tokenize the text into individual words
tokens = word_tokenize(text)

# Step 2: Generate trigrams (groups of three consecutive words) using NLTK
trigrams_list = list(trigrams(tokens))

# Step 3: Display the generated trigrams
print("Sentence:", text)
print("\nGenerated Trigrams:")
print(trigrams_list)
# Out:
# Sentence: Deep learning is a subset of machine learning.
#
# Generated Trigrams:
# [('Deep', 'learning', 'is'), ('learning', 'is', 'a'), ('is', 'a', 'subset'), ('a', 'subset', 'of'), ('subset', 'of', 'machine'), ('of', 'machine', 'learning'), ('machine', 'learning', '.')]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
